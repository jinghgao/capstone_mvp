# %%
# === Strict NLU Intent Evaluation (no heuristics) ===
# Evaluate 5 classes: RAG, RAG+SQL_tool, RAG+CV_tool, CV_tool, SQL_tool

# --- Auto-install required packages if missing ---
import importlib
import subprocess
import sys

required_packages = [
    "numpy",
    "pandas",
    "scikit-learn",
    "matplotlib",
    "sentence-transformers"  # not used here directly but required by nlu.py
]

for pkg in required_packages:
    try:
        importlib.import_module(pkg)
    except ImportError:
        print(f"Installing missing package: {pkg} ...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", pkg])

# --- Imports (after ensuring they exist) ---
from pathlib import Path
from typing import Optional
import importlib.util
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt

INTENTS = ["RAG", "RAG+SQL_tool", "RAG+CV_tool", "CV_tool", "SQL_tool"]

def synthesize_examples() -> pd.DataFrame:
    """
    Generate 10 test examples per intent.
    Each query is semantically close to the few-shot prototypes in nlu.INTENT_PROTOTYPES
    but phrased differently to avoid overlap.
    """
    data = []

    # --- RAG: textual guidance / procedures / standards ---
    rag_queries = [
        "Describe the correct process for trimming park lawns.",
        "How should mowing blades be adjusted for safety?",
        "What are the basic turf maintenance rules for summer?",
        "Give me the official mowing protocol for public fields.",
        "Outline how to prepare turf before large events.",
        "Explain how to safely refuel and clean a mower.",
        "List inspection steps before operating mowing equipment.",
        "What is the standard grass height for soccer practice areas?",
        "How often should turf be aerated under heavy use?",
        "Summarize recommended post-mowing cleanup procedures.",
    ]
    for q in rag_queries:
        data.append({"text": q, "image_uri": None, "label": "RAG"})

    # --- SQL_tool: structured queries only (no interpretation) ---
    sql_queries = [
        "Show total mowing cost by park for Q2 2025.",
        "Give me average mowing hours per week this May.",
        "List top 10 parks by irrigation repair cost.",
        "Display mowing frequency by park for July.",
        "Fetch the park with the lowest mowing expense in April.",
        "Return number of mowing operations completed last month.",
        "Provide total maintenance cost for June 2025 as a table.",
        "Show ranking of parks by total mowing labor hours.",
        "Get monthly mowing expenses for each district.",
        "List mean and median mowing cost per park this quarter.",
    ]
    for q in sql_queries:
        data.append({"text": q, "image_uri": None, "label": "SQL_tool"})

    # --- RAG+SQL_tool: data + interpretation grounded in standards/policy ---
    rag_sql_queries = [
        "Interpret why mowing expenses increased in April compared to March using mowing policies.",
        "Explain cost variation across parks based on mowing interval recommendations.",
        "Discuss if July mowing costs align with approved maintenance frequency.",
        "Analyze whether irrigation spending in Q2 follows standard repair schedules.",
        "Evaluate high mowing cost trends with respect to staff allocation norms.",
        "Provide reasoning for decreased mowing hours using turf condition policies.",
        "Assess if August mowing data matches standard seasonal frequency.",
        "Discuss correlation between mowing labor cost and weather conditions referencing SOPs.",
        "Explain cost efficiency differences among parks using mowing best practices.",
        "Summarize if Q3 2024 mowing costs meet operational benchmarks.",
    ]
    for q in rag_sql_queries:
        data.append({"text": q, "image_uri": None, "label": "RAG+SQL_tool"})

    # --- RAG+CV_tool: image + textual reasoning (needs explanation) ---
    rag_cv_queries = [
        "Look at this picture and explain whether mowing is due according to standards.",
        "From this image, judge turf quality and reference mowing policy.",
        "Analyze this field photo and describe what maintenance should be scheduled.",
        "Check this image and tell me if mowing height meets the guideline.",
        "Use the picture to determine soil compaction and recommend action per SOP.",
        "Based on this photo, suggest next maintenance steps referencing mowing frequency rules.",
        "Examine this image and cite mowing procedures relevant to visible damage.",
        "Review this field photo and discuss mowing uniformity with reference to regulation height.",
        "Using this image, decide if the area needs mowing per standard thresholds.",
        "Assess this picture and explain maintenance tasks according to policy.",
    ]
    for q in rag_cv_queries:
        data.append({"text": q, "image_uri": "file://example_image.jpg", "label": "RAG+CV_tool"})

    # --- CV_tool: pure visual judgment (no textual grounding) ---
    cv_only_queries = [
        "Evaluate the turf condition shown in this image.",
        "Rate the field surface from this picture.",
        "Identify visible issues in the uploaded photo.",
        "Assess turf evenness from the provided image.",
        "Judge mowing quality in this field picture.",
        "From this image, rate turf density from 1 to 5.",
        "Detect any bare patches in this photo.",
        "Check if the grass appears overgrown in this image.",
        "Classify the field condition based on the picture.",
        "Visually estimate mowing height from the image only.",
    ]
    for q in cv_only_queries:
        data.append({"text": q, "image_uri": "file://example_image.jpg", "label": "CV_tool"})

    return pd.DataFrame(data)

# Build dataset
df = synthesize_examples()

# --- Load your nlu.py and call parse_intent_and_slots ---
CURRENT_DIR = Path(__file__).parent if "__file__" in locals() else Path.cwd()
NLU_PATH = (CURRENT_DIR.parent / "nlu.py").resolve()  # notebook in experiment/, nlu.py one level up
print("NLU path resolved to:", NLU_PATH)

# Build a module spec from the resolved path
spec = importlib.util.spec_from_file_location("user_nlu", str(NLU_PATH))

# Create a module object from the spec
module = importlib.util.module_from_spec(spec)

# Register the module in sys.modules BEFORE executing it
# This ensures decorators like @dataclass can resolve the module via cls.__module__
sys.modules[spec.name] = module

# Execute the module code so its symbols are available
spec.loader.exec_module(module)

# Sanity check: the required entrypoint must exist
assert hasattr(module, "parse_intent_and_slots"), "parse_intent_and_slots not found in nlu.py"

# === Option A: intent-only evaluation ===
from dataclasses import is_dataclass

def predict_intent_only(text: str, image_uri: Optional[str]) -> str:
    """
    Call NLU and return only the intent for accuracy/confusion metrics.
    """
    res = module.parse_intent_and_slots(text=text, image_uri=image_uri)
    if is_dataclass(res):
        return getattr(res, "intent")
    if isinstance(res, dict):
        return res.get("intent")
    # Defensive fallback for unexpected return types
    return str(getattr(res, "intent", None))

df["pred_intent"] = df.apply(lambda r: predict_intent_only(r["text"], r["image_uri"]), axis=1)

# --- Metrics (overall) ---
y_true, y_pred = df["label"].values, df["pred_intent"].values
print("Overall Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("\nClassification Report (macro):\n")
print(classification_report(y_true, y_pred, labels=INTENTS, zero_division=0))

# --- Per-class detailed breakdown ---
def print_per_class_breakdown(df: pd.DataFrame, intents: list[str]) -> None:
    """
    Print detailed metrics and examples per class:
    - precision/recall/f1/support from classification_report
    - correct / total / accuracy per class
    - top-3 confusion destinations for each class
    - up to 3 misclassified examples for each class
    """
    report_dict = classification_report(
        df["label"].values,
        df["pred_intent"].values,
        labels=intents,
        output_dict=True,
        zero_division=0,
    )
    cm = confusion_matrix(df["label"].values, df["pred_intent"].values, labels=intents)

    print("\n=== Per-class Breakdown ===")
    for idx, cls in enumerate(intents):
        # Basic metrics from report
        cls_metrics = report_dict.get(cls, {})
        precision = cls_metrics.get("precision", 0.0)
        recall = cls_metrics.get("recall", 0.0)
        f1 = cls_metrics.get("f1-score", 0.0)
        support = int(cls_metrics.get("support", 0))

        # Accuracy per class = diagonal / row sum
        row = cm[idx, :]
        total = int(row.sum())
        correct = int(row[idx]) if total > 0 else 0
        acc = correct / total if total > 0 else 0.0

        print(f"\n--- Class: {cls} ---")
        print(f"precision={precision:.3f}  recall={recall:.3f}  f1={f1:.3f}  support={support}")
        print(f"per-class accuracy: {correct}/{total} = {acc:.3f}")

        # Top-3 confusion destinations (excluding the diagonal)
        confusions = [(intents[j], int(row[j])) for j in range(len(intents)) if j != idx and row[j] > 0]
        confusions.sort(key=lambda x: x[1], reverse=True)
        if confusions:
            topk = confusions[:3]
            topk_str = ", ".join([f"{dst}:{cnt}" for dst, cnt in topk])
            print(f"top confusions → {topk_str}")
        else:
            print("top confusions → (none)")

        # Show up to 3 misclassified examples for this true class
        mis = df[(df["label"] == cls) & (df["pred_intent"] != cls)][["text", "pred_intent"]].head(3)
        if len(mis) > 0:
            print("examples (misclassified):")
            for i, row_ex in mis.iterrows():
                # Truncate long text for readability
                txt = row_ex["text"]
                if len(txt) > 140:
                    txt = txt[:137] + "..."
                print(f"  - pred={row_ex['pred_intent']} | {txt}")
        else:
            print("examples (misclassified): (none)")

print_per_class_breakdown(df, INTENTS)

# --- Confusion Matrix (plot) ---
cm = confusion_matrix(y_true, y_pred, labels=INTENTS)
plt.figure(figsize=(6.8, 5.6))
plt.imshow(cm, interpolation='nearest')
plt.title('NLU Intent Confusion Matrix (5 intents) — parse_intent_and_slots')
plt.xlabel('Predicted'); plt.ylabel('True')
plt.xticks(np.arange(len(INTENTS)), INTENTS, rotation=45, ha='right')
plt.yticks(np.arange(len(INTENTS)), INTENTS)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j, i, str(cm[i, j]), ha='center', va='center')
plt.tight_layout(); plt.show()

# --- Export misclassified for debugging ---
errors = df[df["label"] != df["pred_intent"]][["text","image_uri","label","pred_intent"]]
errors.to_csv("nlu_eval_misclassified_strict.csv", index=False)
df.to_csv("nlu_eval_dataset_strict.csv", index=False)
print("Saved: nlu_eval_dataset_strict.csv, nlu_eval_misclassified_strict.csv")
# Out:
# Installing missing package: scikit-learn ...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: scikit-learn in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from scikit-learn) (1.16.2)
# Requirement already satisfied: joblib>=1.2.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Installing missing package: sentence-transformers ...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: sentence-transformers in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (5.1.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (4.57.0)
# Requirement already satisfied: tqdm in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (0.35.3)
# Requirement already satisfied: Pillow in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: numpy>=1.17 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.9.18)
# Requirement already satisfied: requests in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.10)
# Requirement already satisfied: sympy in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.2.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/siyunhe/anaconda3/envs/capstone/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# NLU path resolved to: /Users/siyunhe/Desktop/neu/capstone/capstone_mvp/nlu.py
# [NLU] Initial intent: RAG (confidence: 0.597)
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': 'Trimming', 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.687)
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.688)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: RAG (confidence: 0.675)
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.633)
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.472)
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.708)
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.554)
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.632)
# [NLU] Final intent: RAG
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.746)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.782)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': 2025, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: SQL_tool (confidence: 0.730)
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': 5, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.645)
# [NLU] SQL-general cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: generic
# [NLU] Extracted slots: {'domain': 'generic', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.646)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': 7, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: SQL_tool (confidence: 0.823)
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': 4, 'year': None, 'start_month': 4, 'end_month': 4, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: SQL_tool (confidence: 0.655)
# [NLU] SQL-general cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: SQL_tool (confidence: 0.489)
# [NLU] Final intent: SQL_tool
# [NLU] Domain: generic
# [NLU] Extracted slots: {'domain': 'generic', 'month': 6, 'year': 2025, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: SQL_tool (confidence: 0.795)
# [NLU] SQL-general cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: SQL_tool (confidence: 0.602)
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.824)
# [NLU] SQL-general cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.833)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': 3, 'year': None, 'start_month': 4, 'end_month': 4, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: SQL_tool (confidence: 0.793)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.773)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': 7, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.839)
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: generic
# [NLU] Extracted slots: {'domain': 'generic', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.757)
# [NLU] SQL-general cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.676)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.600)
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': 8, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.637)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: SQL_tool (confidence: 0.778)
# [NLU] SQL + (policy/info/explain) detected → intent=RAG+SQL_tool
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': True}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.724)
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': 2024, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': None, 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.700)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Image detected; upgrading RAG → RAG+CV_tool
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.765)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.607)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: CV_tool
# [NLU] Domain: field_standards
# [NLU] Extracted slots: {'domain': 'field_standards', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.721)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Image detected; upgrading RAG → RAG+CV_tool
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.371)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Image detected; upgrading RAG → RAG+CV_tool
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: generic
# [NLU] Extracted slots: {'domain': 'generic', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+SQL_tool (confidence: 0.703)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: RAG+SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.665)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Informational keywords detected → intent=RAG
# [NLU] Image detected; upgrading RAG → RAG+CV_tool
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.716)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG (confidence: 0.634)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Image detected; upgrading RAG → RAG+CV_tool
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.462)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: generic
# [NLU] Extracted slots: {'domain': 'generic', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.869)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.701)
# [NLU] SQL-only cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: field_standards
# [NLU] Extracted slots: {'domain': 'field_standards', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.450)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: CV_tool
# [NLU] Domain: generic
# [NLU] Extracted slots: {'domain': 'generic', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.824)
# [NLU] SQL-only cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.771)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: RAG+CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.731)
# [NLU] SQL-only cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.367)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: CV_tool
# [NLU] Domain: generic
# [NLU] Extracted slots: {'domain': 'generic', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.639)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: CV_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: CV_tool (confidence: 0.614)
# [NLU] CV context detected; defer to Step 4 for potential upgrade
# [NLU] Final intent: CV_tool
# [NLU] Domain: field_standards
# [NLU] Extracted slots: {'domain': 'field_standards', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# [NLU] Initial intent: RAG+CV_tool (confidence: 0.580)
# [NLU] SQL-only cues detected → intent=SQL_tool
# [NLU] Final intent: SQL_tool
# [NLU] Domain: mowing
# [NLU] Extracted slots: {'domain': 'mowing', 'month': None, 'year': None, 'start_month': None, 'end_month': None, 'range_year': None, 'park_name': None, 'image_uri': 'file://example_image.jpg', 'explanation_requested': False}
# Overall Accuracy: 0.76
#
# Classification Report (macro):
#
#               precision    recall  f1-score   support
#
#          RAG       1.00      0.80      0.89        10
# RAG+SQL_tool       0.64      0.90      0.75        10
#  RAG+CV_tool       0.89      0.80      0.84        10
#      CV_tool       0.83      0.50      0.62        10
#     SQL_tool       0.62      0.80      0.70        10
#
#     accuracy                           0.76        50
#    macro avg       0.80      0.76      0.76        50
# weighted avg       0.80      0.76      0.76        50
#
#
# === Per-class Breakdown ===
#
# --- Class: RAG ---
# precision=1.000  recall=0.800  f1=0.889  support=10
# per-class accuracy: 8/10 = 0.800
# top confusions → RAG+SQL_tool:2
# examples (misclassified):
#   - pred=RAG+SQL_tool | What are the basic turf maintenance rules for summer?
#   - pred=RAG+SQL_tool | Summarize recommended post-mowing cleanup procedures.
#
# --- Class: RAG+SQL_tool ---
# precision=0.643  recall=0.900  f1=0.750  support=10
# per-class accuracy: 9/10 = 0.900
# top confusions → SQL_tool:1
# examples (misclassified):
#   - pred=SQL_tool | Evaluate high mowing cost trends with respect to staff allocation norms.
#
# --- Class: RAG+CV_tool ---
# precision=0.889  recall=0.800  f1=0.842  support=10
# per-class accuracy: 8/10 = 0.800
# top confusions → RAG+SQL_tool:1, CV_tool:1
# examples (misclassified):
#   - pred=CV_tool | Analyze this field photo and describe what maintenance should be scheduled.
#   - pred=RAG+SQL_tool | Based on this photo, suggest next maintenance steps referencing mowing frequency rules.
#
# --- Class: CV_tool ---
# precision=0.833  recall=0.500  f1=0.625  support=10
# per-class accuracy: 5/10 = 0.500
# top confusions → SQL_tool:4, RAG+CV_tool:1
# examples (misclassified):
#   - pred=SQL_tool | Rate the field surface from this picture.
#   - pred=SQL_tool | Assess turf evenness from the provided image.
#   - pred=RAG+CV_tool | Judge mowing quality in this field picture.
#
# --- Class: SQL_tool ---
# precision=0.615  recall=0.800  f1=0.696  support=10
# per-class accuracy: 8/10 = 0.800
# top confusions → RAG+SQL_tool:2
# examples (misclassified):
#   - pred=RAG+SQL_tool | Show total mowing cost by park for Q2 2025.
#   - pred=RAG+SQL_tool | Display mowing frequency by park for July.
# Saved: nlu_eval_dataset_strict.csv, nlu_eval_misclassified_strict.csv
