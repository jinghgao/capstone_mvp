# %% [markdown]
# # SQL Template Smoke Tests
#
# A cell per template in `sql_tool.TEMPLATE_REGISTRY`. Run individual cells to sanity-check outputs without a loop.

# %%
import os, sys

# Ensure project root is importable when running from the experiment folder
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
# Avoid rebuilding the DB from missing Excel files: point DataLayer to existing SQLite
import Data_layer
def _use_existing_db(self):
    self.db_path = os.path.join(project_root, "data", "parks_data.sqlite3")
    self.connection = None
    return self
Data_layer.DataLayer.initialize_database = _use_existing_db

from sql_tool import run_sql_template

print(f"Project root: {project_root}")
# Out:
# Project root: /Users/jinghgao/Documents/GitHub/CS7980/urban-park-multimodal-ai

# %% [markdown]
# ## mowing.labor_cost_month_top1

# %%
res = run_sql_template(
    "mowing.labor_cost_month_top1",
    {"month": 3, "year": 2025},
)

res

# Which park had the highest total mowing labor cost in March 2025?
# Out:
# {'rows': [{'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'total_cost': 2963.4700000000003}],
#  'rowcount': 1,
#  'elapsed_ms': 6}

# %% [markdown]
# ## mowing.last_mowing_date

# %%
res = run_sql_template(
    "mowing.last_mowing_date",
    {"park_name": "Cambridge"},
)

res

# When was the last mowing at Cambridge Park?
# Out:
# Elapsed time: 5 ms
# {'rows': [{'park': 'RFT- Cambridge Pk PTurf Mow/Maint',
#    'last_mowing_date': '2025-06-03 00:00:00',
#    'total_mowing_sessions': 7,
#    'total_cost': 431.55999999999995}],
#  'rowcount': 1,
#  'elapsed_ms': 5}

# %% [markdown]
# ## mowing.cost_trend

# %%
res = run_sql_template(
    "mowing.cost_trend",
    {"start_month": 1, "end_month": 6, "year": 2025},
)

res
# Show mowing cost trend from January to June 2025
# Out:
# {'rows': [{'year': '2025',
#    'month': '01',
#    'park': '"RFT- Brewers Pk ""B"" Fields Mowing"',
#    'monthly_cost': 81.3,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': '"RFT- Clinton Pk ""A"" Fields Mowing"',
#    'monthly_cost': 30.32,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': '"RFT- Slocan Pk ""B"" Fields Mowing"',
#    'monthly_cost': 39.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Aberdeen Pk PTurf Mow/Maint',
#    'monthly_cost': 311.56,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 77.89,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Cambridge Pk PTurf Mow/Maint',
#    'monthly_cost': 120.25,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 842.24,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 60.63,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Charles Pk PTurf Mow/Maint',
#    'monthly_cost': 64.1,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Falaise Pk PTurf Mow/Maint',
#    'monthly_cost': 119.38,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Grandview Pk PTurf Mow/Maint',
#    'monthly_cost': 197.83,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Grimmet Pk PTurf Mow/Maint',
#    'monthly_cost': 38.95,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 514.9,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 155.79000000000002,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- MacLean Pk PTurf Mow/Maint',
#    'monthly_cost': 128.18,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Mt Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 240.64,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Oxford Pk PTurf Mow/Maint',
#    'monthly_cost': 38.95,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Pandora Pk PTurf Mow/Maint',
#    'monthly_cost': 311.56,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Slocan Pk PTurf Mow/Maint',
#    'monthly_cost': 60.63,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Strathcona Lin. Pk PTurf Mow/Maint',
#    'monthly_cost': 77.89,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 77.89,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Templeton Pk PTurf Mow/Maint',
#    'monthly_cost': 120.32,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Thunderbird Pk PTurf Mow/Maint',
#    'monthly_cost': 64.1,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Trin/Wall Pk Site PTurf Mow/Maint',
#    'monthly_cost': 38.95,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'RFT- Victoria Pk PTurf Mow/Maint',
#    'monthly_cost': 276.96000000000004,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 50.29,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Cambridge Pk PTurf Mow/Maint',
#    'monthly_cost': 125.72999999999999,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Dusty Greenwell Pk PTurf Mow/Maint',
#    'monthly_cost': 50.29,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'monthly_cost': 487.79999999999995,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Jonathan Rogers Pk PTurf Mow/Maint',
#    'monthly_cost': 100.58,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 100.59,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Mount Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 100.58,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Oxford Pk PTurf Mow/Maint',
#    'monthly_cost': 50.29,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Pandora Pk PTurf Mow/Maint',
#    'monthly_cost': 201.16,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Strathcona Linear Pk PTurf Mow/Main',
#    'monthly_cost': 25.15,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 50.29,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '01',
#    'park': 'TFT- Trinity/Wall Pk Site PTurf Mow/Main',
#    'monthly_cost': 125.73,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '02',
#    'park': '"RFT- Garden Pk ""B"" Fields Mowing"',
#    'monthly_cost': 60.63,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '02',
#    'park': '"RFT- Hastings Pk ""A"" Fields Mowing"',
#    'monthly_cost': 39.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '02',
#    'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 361.94,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '02',
#    'park': 'RFT- Charles Pk PTurf Mow/Maint',
#    'monthly_cost': 238.84,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '02',
#    'park': 'RFT- Clark Pk PTurf Mow/Maint',
#    'monthly_cost': 120.32,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '02',
#    'park': 'RFT- Gaston Pk PTurf Mow/Maint',
#    'monthly_cost': 121.26,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '02',
#    'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 108.4,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '02',
#    'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 1399.5400000000002,
#    'session_count': 8},
#   {'year': '2025',
#    'month': '02',
#    'park': 'TFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 201.16,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '02',
#    'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'monthly_cost': 135.5,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': '"RFT- Templeton Pk- ""B"" Fields Mowing"',
#    'monthly_cost': 119.38,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 2963.4700000000003,
#    'session_count': 15},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 120.32,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- China Cr Pk S PTurf Mow/Maint',
#    'monthly_cost': 194.73,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Evans Yard PTurf Mow/Maint',
#    'monthly_cost': 60.63,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Falaise Pk PTurf Mow/Maint',
#    'monthly_cost': 118.7,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Gaston Pk PTurf Mow/Maint',
#    'monthly_cost': 238.84,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Hastings CC Pk PTurf Mow/Maint',
#    'monthly_cost': 798.04,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Hastings Pk PTurf Mow/Maint',
#    'monthly_cost': 655.3,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 1253.8799999999999,
#    'session_count': 8},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 269.68,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Melbourne Pk PTurf Mow/Maint',
#    'monthly_cost': 119.42,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 1709.14,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Price Pk PTurf Mow/Maint',
#    'monthly_cost': 59.69,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 376.64,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Strathcona Pk PTurf Mow/Maint',
#    'monthly_cost': 120.32,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 897.9699999999999,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '03',
#    'park': 'RFT- Thunderbird Pk PTurf Mow/Maint',
#    'monthly_cost': 61.45,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '03',
#    'park': 'TFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 955.51,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '03',
#    'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'monthly_cost': 238.84,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '03',
#    'park': 'TFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 104.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Adanac Pk ""A"" Fields Mowing"',
#    'monthly_cost': 184.59,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Adanac Pk ""B"" Fields Mowing"',
#    'monthly_cost': 61.53,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Beaconsfield Pk ""A"" Fields Mowin',
#    'monthly_cost': 492.2399999999999,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Brewers Pk ""B"" Fields Mowing"',
#    'monthly_cost': 246.12,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Clark Pk ""B"" Fields Mowing"',
#    'monthly_cost': 184.59,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Clinton Pk ""A"" Fields Mowing"',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Clinton Pk ""B"" Fields Mowing"',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Collingwood Pk ""B"" Fields Mowing',
#    'monthly_cost': 246.12,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Falaise Pk ""A"" Fields Mowing"',
#    'monthly_cost': 307.65,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Falaise Pk ""B"" Fields Mowing"',
#    'monthly_cost': 184.59,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Gaston Pk ""A"" Fields Mowing"',
#    'monthly_cost': 307.65,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- General Brock Pk ""B"" Fields Mow"',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Hastings CC Pk ""B"" Fields Mowing',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Hastings Pk ""A"" Fields Mowing"',
#    'monthly_cost': 123.07,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- John Hendry Pk ""A"" Fields Mowing',
#    'monthly_cost': 296.63,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- John Hendry Pk ""B"" Fields Mowing',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Jon Rogers Pk ""B"" Fields Mowing"',
#    'monthly_cost': 92.3,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- MacLean Pk ""A"" Fields Mowing"',
#    'monthly_cost': 153.83,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Prince Edward Pk ""B"" Fields Mowi',
#    'monthly_cost': 246.12,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Renfrew Pk ""A"" Fields Mowing"',
#    'monthly_cost': 369.17999999999995,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Robson Pk ""B"" Fields Mowing"',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Rupert Pk ""A"" Fields Mowing"',
#    'monthly_cost': 276.89,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Slocan Pk ""A"" Fields Mowing"',
#    'monthly_cost': 369.17999999999995,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Slocan Pk ""B"" Fields Mowing"',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Strathcona Pk ""A"" Fields Mowing"',
#    'monthly_cost': 307.65,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Strathcona Pk ""B"" Fields Mowing"',
#    'monthly_cost': 184.59,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Sunrise Pk ""A"" Fields Mowing"',
#    'monthly_cost': 196.3,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Templeton Pk ""A"" Fields Mowing"',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Templeton Pk- ""B"" Fields Mowing"',
#    'monthly_cost': 104.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"RFT- Woodland Pk ""B"" Fields Mowing"',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': '"TFT- MacLean Pk ""A"" Fields Mowing"',
#    'monthly_cost': 470.20000000000005,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': '"TFT- Prince Edward Pk ""B"" Fields Mowi',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': '"TFT- Robson Pk ""B"" Fields Mowing"',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Aberdeen Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Adanac Pk PTurf Mow/Maint',
#    'monthly_cost': 1257.3899999999999,
#    'session_count': 9},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Beaconsfield Pk PTurf Mow/Maint',
#    'monthly_cost': 627.0799999999999,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Brewers Pk PTurf Mow/Maint',
#    'monthly_cost': 262.15999999999997,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Burrard View Pk PTurf Mow/Maint',
#    'monthly_cost': 674.3599999999999,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 662.4200000000001,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Cambridge Pk PTurf Mow/Maint',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 563.13,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- China Cr Pk N PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Clark Pk PTurf Mow/Maint',
#    'monthly_cost': 248.2,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Clinton Pk PTurf Mow/Maint',
#    'monthly_cost': 1025.85,
#    'session_count': 12},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Collingwood Pk PTurf Mow/Maint',
#    'monthly_cost': 861.42,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Evans Yard PTurf Mow/Maint',
#    'monthly_cost': 281.14,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Falaise Pk PTurf Mow/Maint',
#    'monthly_cost': 653.44,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Garden Pk PTurf Mow/Maint',
#    'monthly_cost': 278.45,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Gaston Pk PTurf Mow/Maint',
#    'monthly_cost': 1230.6,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- General Brock Pk PTurf Mow/Maint',
#    'monthly_cost': 363.81,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Glen Pk PTurf Mow/Maint',
#    'monthly_cost': 371.26,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Grandview Pk PTurf Mow/Maint',
#    'monthly_cost': 184.59,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Grimmet Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Guelph Pk PTurf Mow/Maint',
#    'monthly_cost': 155.39,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Hastings CC Pk PTurf Mow/Maint',
#    'monthly_cost': 894.4499999999999,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Hastings Pk PTurf Mow/Maint',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 4230.4800000000005,
#    'session_count': 25},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Jon Rogers Pk PTurf Mow/Maint',
#    'monthly_cost': 92.3,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 612.8299999999999,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- MacLean Pk PTurf Mow/Maint',
#    'monthly_cost': 92.3,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- McGill Pk PTurf Mow/Maint',
#    'monthly_cost': 104.16,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- McSpadden Pk PTurf Mow/Maint',
#    'monthly_cost': 153.82999999999998,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Melbourne Pk PTurf Mow/Maint',
#    'monthly_cost': 1476.72,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Mt Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 499.52000000000004,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 2996.85,
#    'session_count': 12},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- North- Lilian To- PTurf/Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Oppenheimer Pk PTurf Mow/Maint',
#    'monthly_cost': 560.6999999999999,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Pandora Pk PTurf Mow/Maint',
#    'monthly_cost': 208.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Price Pk PTurf Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 430.11,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Renfrew Ravine Pk PTurf Mow/Maint',
#    'monthly_cost': 321.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Rupert Pk PTurf Mow/Maint',
#    'monthly_cost': 1201.94,
#    'session_count': 10},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Sahalli Pk PTurf Mow/Maint',
#    'monthly_cost': 154.87,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Salsbury Pk PTurf Mow/Maint',
#    'monthly_cost': 93.86,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Slocan Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Strathcona Pk PTurf Mow/Maint',
#    'monthly_cost': 586.11,
#    'session_count': 10},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Sun Hop Pk PTurf Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Sunnyside Pk PTurf Mow/Maint',
#    'monthly_cost': 684.1099999999999,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 858.7899999999998,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Tea Swamp Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Templeton Pk PTurf Mow/Maint',
#    'monthly_cost': 621.55,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Thornton Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Thunderbird Pk PTurf Mow/Maint',
#    'monthly_cost': 466.04999999999995,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Trillium Pk- Pass. Turf Mow/Maint',
#    'monthly_cost': 476.03999999999996,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Victoria Pk PTurf Mow/Maint',
#    'monthly_cost': 290.01,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- WC Shelley Pk PTurf Mow/Maint',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'RFT- Woodland Pk PTurf Mow/Maint',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Adanac Pk PTurf Mow/Maint',
#    'monthly_cost': 260.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Bates Pk PTurf Mow/Maint',
#    'monthly_cost': 217.45,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Beaconsfield Pk PTurf Mow/Maint',
#    'monthly_cost': 312.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 208.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 832.0,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 104.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- China Crk Pk South PTurf Mow/Maint',
#    'monthly_cost': 123.06,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Clinton Pk PTurf Mow/Maint',
#    'monthly_cost': 288.35,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Garden Pk PTurf Mow/Maint',
#    'monthly_cost': 78.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- General Brock Pk PTurf Mow/Maint',
#    'monthly_cost': 364.0,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Glen Pk PTurf Mow/Maint',
#    'monthly_cost': 104.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Grimmet Pk PTurf Mow/Maint',
#    'monthly_cost': 165.53,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Guelph Pk PTurf Mow/Maint',
#    'monthly_cost': 156.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Hastings CC Pk PTurf Mow/Maint',
#    'monthly_cost': 208.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'monthly_cost': 1019.38,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Hastings Pk PTurf Mow/Maint',
#    'monthly_cost': 661.8,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 286.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- MacLean Pk PTurf Mow/Maint',
#    'monthly_cost': 420.15,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Mount Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 572.0,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 1117.96,
#    'session_count': 8},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- North- Lilian To- PTurf/Mow/Maint',
#    'monthly_cost': 52.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Oppenheimer Pk PTurf Mow/Maint',
#    'monthly_cost': 1106.1499999999999,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Price Pk PTurf Mow/Maint',
#    'monthly_cost': 52.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 104.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Rupert Pk PTurf Mow/Maint',
#    'monthly_cost': 312.0,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Salsbury Pk PTurf Mow/Maint',
#    'monthly_cost': 78.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Strathcona Linear Pk PTurf Mow/Main',
#    'monthly_cost': 772.8,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Strathcona Pk PTurf Mow/Maint',
#    'monthly_cost': 884.0,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Sunnyside Pk PTurf Mow/Maint',
#    'monthly_cost': 312.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Tea Swamp Pk PTurf Mow/Maint',
#    'monthly_cost': 52.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Templeton Pk PTurf Mow/Maint',
#    'monthly_cost': 340.35,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Trillium Pk- Pass. Turf Mow/Maint',
#    'monthly_cost': 567.25,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '04',
#    'park': 'TFT- Victoria Pk PTurf Mow/Maint',
#    'monthly_cost': 340.35,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Adanac Pk ""A"" Fields Mowing"',
#    'monthly_cost': 523.01,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Brewers Pk ""B"" Fields Mowing"',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- China Cr. Pk N ""A"" Fields Mowing',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Clark Pk ""B"" Fields Mowing"',
#    'monthly_cost': 93.34,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Clinton Pk ""A"" Fields Mowing"',
#    'monthly_cost': 199.99,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Clinton Pk ""B"" Fields Mowing"',
#    'monthly_cost': 138.46,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Collingwood Pk ""B"" Fields Mowing',
#    'monthly_cost': 93.34,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Falaise Pk ""A"" Fields Mowing"',
#    'monthly_cost': 153.84,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Falaise Pk ""B"" Fields Mowing"',
#    'monthly_cost': 153.84,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Gaston Pk ""A"" Fields Mowing"',
#    'monthly_cost': 124.11,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Hastings Pk ""A"" Fields Mowing"',
#    'monthly_cost': 123.08,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- John Hendry Pk ""A"" Fields Mowing',
#    'monthly_cost': 1223.7399999999998,
#    'session_count': 13},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- New Brighton Pk ""B"" Fields Mowin',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Oppenheimer Pk ""A"" Fields Mowing',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Prince Edward Pk ""B"" Fields Mowi',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Rupert Pk ""A"" Fields Mowing"',
#    'monthly_cost': 492.24999999999994,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Slocan Pk ""A"" Fields Mowing"',
#    'monthly_cost': 93.34,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Slocan Pk ""B"" Fields Mowing"',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Sunrise Pk ""A"" Fields Mowing"',
#    'monthly_cost': 101.85,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Templeton Pk- ""B"" Fields Mowing"',
#    'monthly_cost': 9.530000000000001,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': '"RFT- Woodland Pk ""B"" Fields Mowing"',
#    'monthly_cost': 92.31,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Beaconsfield Pk ""A"" Fields Mowin',
#    'monthly_cost': 307.65999999999997,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- China Creek Pk N ""A"" Fields Mowi',
#    'monthly_cost': 653.3199999999999,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Garden Pk ""B"" Fields Mowing"',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- John Hendry Pk ""B"" Fields Mowing',
#    'monthly_cost': 52.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Jonathan Rogers Pk ""B"" Fields Mo',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- MacLean Pk ""A"" Fields Mowing"',
#    'monthly_cost': 369.18999999999994,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- McSpadden Pk ""B"" Fields Mowing"',
#    'monthly_cost': 123.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Prince Edward Pk ""B"" Fields Mowi',
#    'monthly_cost': 92.3,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Renfrew Pk ""A"" Fields Mowing"',
#    'monthly_cost': 184.59,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Robson Pk ""B"" Fields Mowing"',
#    'monthly_cost': 152.71,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Slocan Pk ""A"" Fields Mowing"',
#    'monthly_cost': 215.36,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Slocan Pk ""B"" Fields Mowing"',
#    'monthly_cost': 215.35999999999999,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Strathcona Pk ""A"" Fields Mowing"',
#    'monthly_cost': 577.8499999999999,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Strathcona Pk ""B"" Fields Mowing"',
#    'monthly_cost': 672.3799999999999,
#    'session_count': 8},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Templeton Pk ""A"" Fields Mowing"',
#    'monthly_cost': 584.54,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': '"TFT- Templeton Pk- ""B"" Fields Mowing"',
#    'monthly_cost': 430.7199999999999,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Aberdeen Pk PTurf Mow/Maint',
#    'monthly_cost': 531.33,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Adanac Pk PTurf Mow/Maint',
#    'monthly_cost': 1005.3299999999999,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Alice Town. Pk PTurf Mow/Maint',
#    'monthly_cost': 219.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Bates Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Beaconsfield Pk PTurf Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Brewers Pk PTurf Mow/Maint',
#    'monthly_cost': 1002.21,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Burrard View Pk PTurf Mow/Maint',
#    'monthly_cost': 1066.53,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 600.9,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Cambridge Pk PTurf Mow/Maint',
#    'monthly_cost': 249.76999999999998,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 312.85,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 312.85,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Cedar Cottage Pk PTurf Mow/Main',
#    'monthly_cost': 406.71000000000004,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Charles Pk PTurf Mow/Maint',
#    'monthly_cost': 1175.77,
#    'session_count': 8},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Clark Pk PTurf Mow/Maint',
#    'monthly_cost': 759.1700000000001,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Clinton Pk PTurf Mow/Maint',
#    'monthly_cost': 415.19,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Collingwood Pk PTurf Mow/Maint',
#    'monthly_cost': 2557.4999999999995,
#    'session_count': 9},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Dusty Green Pk PTurf Mow/Maint',
#    'monthly_cost': 361.90000000000003,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Falaise Pk PTurf Mow/Maint',
#    'monthly_cost': 1150.79,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Garden Pk PTurf Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Gaston Pk PTurf Mow/Maint',
#    'monthly_cost': 2016.4999999999995,
#    'session_count': 11},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- General Brock Pk PTurf Mow/Maint',
#    'monthly_cost': 247.01,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Glen Pk PTurf Mow/Maint',
#    'monthly_cost': 76.91,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Grimmet Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Guelph Pk PTurf Mow/Maint',
#    'monthly_cost': 219.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Hastings CC Pk PTurf Mow/Maint',
#    'monthly_cost': 1244.1700000000003,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Hastings Pk PTurf Mow/Maint',
#    'monthly_cost': 423.52,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 4367.299999999999,
#    'session_count': 22},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Jon Rogers Pk PTurf Mow/Maint',
#    'monthly_cost': 250.28,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 539.4399999999999,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- McGill Pk PTurf Mow/Maint',
#    'monthly_cost': 435.28999999999996,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- McSpadden Pk PTurf Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Melbourne Pk PTurf Mow/Maint',
#    'monthly_cost': 1656.85,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Mjr Matthews Pk PTurf Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Mosaic Creek Pk PTurf Mow/Maint',
#    'monthly_cost': 625.7,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Mt Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 609.28,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 2525.5099999999998,
#    'session_count': 11},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- North- Lilian To- PTurf/Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Oppenheimer Pk PTurf Mow/Maint',
#    'monthly_cost': 406.71,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Oxford Pk PTurf Mow/Maint',
#    'monthly_cost': 219.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Pandora Pk PTurf Mow/Maint',
#    'monthly_cost': 207.81,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Price Pk PTurf Mow/Maint',
#    'monthly_cost': 281.05,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 722.59,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Renfrew Ravine Pk PTurf Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Rupert Pk PTurf Mow/Maint',
#    'monthly_cost': 2023.2300000000002,
#    'session_count': 8},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Sahalli Pk PTurf Mow/Maint',
#    'monthly_cost': 156.43,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Salsbury Pk PTurf Mow/Maint',
#    'monthly_cost': 406.71000000000004,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Slocan Pk PTurf Mow/Maint',
#    'monthly_cost': 311.81,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Strathcona Pk PTurf Mow/Maint',
#    'monthly_cost': 969.84,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Sun Hop Pk PTurf Mow/Maint',
#    'monthly_cost': 375.42,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Sunnyside Pk PTurf Mow/Maint',
#    'monthly_cost': 46.15,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 1502.1499999999999,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Tea Swamp Pk PTurf Mow/Maint',
#    'monthly_cost': 250.28,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Templeton Pk PTurf Mow/Maint',
#    'monthly_cost': 219.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Thornton Pk PTurf Mow/Maint',
#    'monthly_cost': 219.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Thunderbird Pk PTurf Mow/Maint',
#    'monthly_cost': 558.27,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Trillium Pk- Pass. Turf Mow/Maint',
#    'monthly_cost': 93.86,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Victoria Pk PTurf Mow/Maint',
#    'monthly_cost': 124.1,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- WC Shelley Pk PTurf Mow/Maint',
#    'monthly_cost': 344.14,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'RFT- Woodland Pk PTurf Mow/Maint',
#    'monthly_cost': 92.31,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Aberdeen Pk PTurf Mow/Maint',
#    'monthly_cost': 794.15,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Adanac Pk PTurf Mow/Maint',
#    'monthly_cost': 624.0,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Alice Townley Pk PTurf Mow/Main',
#    'monthly_cost': 614.53,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Bates Pk PTurf Mow/Maint',
#    'monthly_cost': 227.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Beaconsfield Pk PTurf Mow/Maint',
#    'monthly_cost': 729.19,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Brewers Pk PTurf Mow/Maint',
#    'monthly_cost': 931.25,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Burrard View Pk PTurf Mow/Maint',
#    'monthly_cost': 1007.06,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 208.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Cambridge Pk PTurf Mow/Maint',
#    'monthly_cost': 536.61,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 1072.66,
#    'session_count': 9},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 284.6,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Carolina St.End Pk PTurf Mow/Maint',
#    'monthly_cost': 227.06,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Cedar Cottage Pk PTurf Mow/Maint',
#    'monthly_cost': 919.4300000000001,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Charles Pk PTurf Mow/Maint',
#    'monthly_cost': 260.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- China Creek Pk North PTurf Mow/Main',
#    'monthly_cost': 82.77,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- China Crk Pk South PTurf Mow/Maint',
#    'monthly_cost': 1061.51,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Clark Pk PTurf Mow/Maint',
#    'monthly_cost': 2099.53,
#    'session_count': 9},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Clinton Pk PTurf Mow/Maint',
#    'monthly_cost': 572.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Dusty Greenwell Pk PTurf Mow/Maint',
#    'monthly_cost': 312.0,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Evans Yard PTurf Mow/Maint',
#    'monthly_cost': 281.14,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Falaise Pk PTurf Mow/Maint',
#    'monthly_cost': 1549.45,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Garden Pk PTurf Mow/Maint',
#    'monthly_cost': 496.35,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- General Brock Pk PTurf Mow/Maint',
#    'monthly_cost': 232.6,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Glen Pk PTurf Mow/Maint',
#    'monthly_cost': 229.82999999999998,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Grandview Pk PTurf Mow/Maint',
#    'monthly_cost': 1194.8700000000001,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Grimmet Pk PTurf Mow/Maint',
#    'monthly_cost': 260.0,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Guelph Pk PTurf Mow/Maint',
#    'monthly_cost': 671.38,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Hastings CC Pk PTurf Mow/Maint',
#    'monthly_cost': 694.9,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'monthly_cost': 2814.1899999999996,
#    'session_count': 10},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Hastings Pk PTurf Mow/Maint',
#    'monthly_cost': 1077.8,
#    'session_count': 10},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 1184.81,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Jonathan Rogers Pk PTurf Mow/Maint',
#    'monthly_cost': 843.05,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 416.0,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- MacLean Pk PTurf Mow/Maint',
#    'monthly_cost': 1091.93,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Major Matthews Pk PTurf Mow/Maint',
#    'monthly_cost': 269.53,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- McGill Pk PTurf Mow/Maint',
#    'monthly_cost': 260.0,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- McSpadden Pk PTurf Mow/Maint',
#    'monthly_cost': 619.41,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Mosaic Creek Pk PTurf Mow/Maint',
#    'monthly_cost': 2026.8,
#    'session_count': 11},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Mount Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 1001.77,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 3147.95,
#    'session_count': 13},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- North- Lilian To- PTurf/Mow/Maint',
#    'monthly_cost': 278.98,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Oppenheimer Pk PTurf Mow/Maint',
#    'monthly_cost': 919.5900000000001,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Oxford Pk PTurf Mow/Maint',
#    'monthly_cost': 475.08000000000004,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Pandora Pk PTurf Mow/Maint',
#    'monthly_cost': 661.8,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Price Pk PTurf Mow/Maint',
#    'monthly_cost': 284.6,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Prince Edward Pk PTurf Mow/Maint',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 719.58,
#    'session_count': 10},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Renfrew Ravine Pk PTurf Mow/Maint',
#    'monthly_cost': 823.5,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Robson Pk PTurf Mow/Maint',
#    'monthly_cost': 52.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Rupert Pk PTurf Mow/Maint',
#    'monthly_cost': 2018.4,
#    'session_count': 12},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Sahalli Pk PTurf Mow/Maint',
#    'monthly_cost': 475.15999999999997,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Salsbury Pk PTurf Mow/Maint',
#    'monthly_cost': 919.4300000000001,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Slocan Pk PTurf Mow/Maint',
#    'monthly_cost': 269.53,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Strathcona Linear Pk PTurf Mow/Main',
#    'monthly_cost': 153.83,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Strathcona Pk PTurf Mow/Maint',
#    'monthly_cost': 3183.89,
#    'session_count': 17},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Sun Hop Pk PTurf Mow/Maint',
#    'monthly_cost': 626.51,
#    'session_count': 8},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Sunnyside Pk PTurf Mow/Maint',
#    'monthly_cost': 385.83,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 1184.6,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Tea Swamp Pk PTurf Mow/Maint',
#    'monthly_cost': 486.9,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '05',
#    'park': 'TFT- Templeton Pk PTurf Mow/Maint',
#    'monthly_cost': 427.85,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '05',
# ...
#    'month': '06',
#    'park': 'RFT- Beaconsfield Pk PTurf Mow/Maint',
#    'monthly_cost': 599.09,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Brewers Pk PTurf Mow/Maint',
#    'monthly_cost': 491.03,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Burrard View Pk PTurf Mow/Maint',
#    'monthly_cost': 766.5,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 466.04999999999995,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Cambridge Pk PTurf Mow/Maint',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 218.48,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 155.91,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Charles Pk PTurf Mow/Maint',
#    'monthly_cost': 600.89,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- China Cr Pk S PTurf Mow/Maint',
#    'monthly_cost': 184.59,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Clinton Pk PTurf Mow/Maint',
#    'monthly_cost': 600.8900000000001,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Collingwood Pk PTurf Mow/Maint',
#    'monthly_cost': 2742.25,
#    'session_count': 9},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Dusty Green Pk PTurf Mow/Maint',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Evans Yard PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Falaise Pk PTurf Mow/Maint',
#    'monthly_cost': 437.99,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Foster Pk PTurf Mow/Maint',
#    'monthly_cost': 218.48000000000002,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Garden Pk PTurf Mow/Maint',
#    'monthly_cost': 219.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Gaston Pk PTurf Mow/Maint',
#    'monthly_cost': 369.18,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- General Brock Pk PTurf Mow/Maint',
#    'monthly_cost': 248.2,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Glen Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Grandview Pk PTurf Mow/Maint',
#    'monthly_cost': 250.28,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Grimmet Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Guelph Pk PTurf Mow/Maint',
#    'monthly_cost': 249.24,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Hastings CC Pk PTurf Mow/Maint',
#    'monthly_cost': 797.0999999999999,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Hastings Pk PTurf Mow/Maint',
#    'monthly_cost': 185.64,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 4583.31,
#    'session_count': 23},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Jon Rogers Pk PTurf Mow/Maint',
#    'monthly_cost': 250.28,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 435.28999999999996,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- McGill Pk PTurf Mow/Maint',
#    'monthly_cost': 122.98,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- McSpadden Pk PTurf Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Melbourne Pk PTurf Mow/Maint',
#    'monthly_cost': 799.89,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Mjr Matthews Pk PTurf Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Mt Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 186.67000000000002,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 2483.14,
#    'session_count': 14},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- North- Lilian To- PTurf/Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Oppenheimer Pk PTurf Mow/Maint',
#    'monthly_cost': 312.85,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Oxford Pk PTurf Mow/Maint',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Pandora Pk PTurf Mow/Maint',
#    'monthly_cost': 625.19,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Pr Edward Pk PTurf Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Price Pk PTurf Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 227.84,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Renfrew Ravine Pk PTurf Mow/Maint',
#    'monthly_cost': 62.57,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Robson Pk PTurf Mow/Maint',
#    'monthly_cost': 436.95000000000005,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Rupert Pk PTurf Mow/Maint',
#    'monthly_cost': 428.48,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Slocan Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Strathcona Lin. Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Strathcona Pk PTurf Mow/Maint',
#    'monthly_cost': 562.09,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Sun Hop Pk PTurf Mow/Maint',
#    'monthly_cost': 187.71,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Sunnyside Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 587.12,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Tea Swamp Pk PTurf Mow/Maint',
#    'monthly_cost': 125.14,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Templeton Pk PTurf Mow/Maint',
#    'monthly_cost': 469.28,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Thornton Pk PTurf Mow/Maint',
#    'monthly_cost': 153.83,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Thunderbird Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Trillium Pk- Pass. Turf Mow/Maint',
#    'monthly_cost': 436.43999999999994,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Victoria Pk PTurf Mow/Maint',
#    'monthly_cost': 280.45,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'RFT- Woodland Pk PTurf Mow/Maint',
#    'monthly_cost': 218.48000000000002,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Aberdeen Pk PTurf Mow/Maint',
#    'monthly_cost': 628.7,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Adanac Pk PTurf Mow/Maint',
#    'monthly_cost': 572.0,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Alice Townley Pk PTurf Mow/Main',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Beaconsfield Pk PTurf Mow/Maint',
#    'monthly_cost': 309.75,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Brewers Pk PTurf Mow/Maint',
#    'monthly_cost': 262.43,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Burrard View Pk PTurf Mow/Maint',
#    'monthly_cost': 217.53,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Callister Pk PTurf Mow/Maint',
#    'monthly_cost': 184.35,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Cariboo Pk PTurf Mow/Maint',
#    'monthly_cost': 156.0,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Carleton Pk PTurf Mow/Maint',
#    'monthly_cost': 278.9,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Carolina St.End Pk PTurf Mow/Maint',
#    'monthly_cost': 113.53,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Charles Pk PTurf Mow/Maint',
#    'monthly_cost': 208.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- China Creek Pk North PTurf Mow/Main',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- China Crk Pk South PTurf Mow/Maint',
#    'monthly_cost': 510.53,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Clark Pk PTurf Mow/Maint',
#    'monthly_cost': 595.84,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Clinton Pk PTurf Mow/Maint',
#    'monthly_cost': 208.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Evans Yard PTurf Mow/Maint',
#    'monthly_cost': 104.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Falaise Pk PTurf Mow/Maint',
#    'monthly_cost': 492.08000000000004,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Foster Pk PTurf Mow/Maint',
#    'monthly_cost': 153.67000000000002,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Garden Pk PTurf Mow/Maint',
#    'monthly_cost': 397.08000000000004,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- General Brock Pk PTurf Mow/Maint',
#    'monthly_cost': 349.8,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Glen Pk PTurf Mow/Maint',
#    'monthly_cost': 288.43,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Grandview Pk PTurf Mow/Maint',
#    'monthly_cost': 453.8,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Grimmet Pk PTurf Mow/Maint',
#    'monthly_cost': 196.22000000000003,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Guelph Pk PTurf Mow/Maint',
#    'monthly_cost': 340.35,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Hastings CC Pk PTurf Mow/Maint',
#    'monthly_cost': 364.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'monthly_cost': 1400.5,
#    'session_count': 6},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Hastings Pk PTurf Mow/Maint',
#    'monthly_cost': 288.43,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- John Hendry Pk PTurf Mow/Maint',
#    'monthly_cost': 368.94,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Jonathan Rogers Pk PTurf Mow/Maint',
#    'monthly_cost': 453.8,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Kaslo Pk PTurf Mow/Maint',
#    'monthly_cost': 156.0,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- MacLean Pk PTurf Mow/Maint',
#    'monthly_cost': 280.1,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Major Matthews Pk PTurf Mow/Maint',
#    'monthly_cost': 113.53,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- McSpadden Pk PTurf Mow/Maint',
#    'monthly_cost': 340.35,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Melbourne Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Mount Pleasant Pk PTurf Mow/Maint',
#    'monthly_cost': 288.43,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- New Brighton Pk PTurf Mow/Maint',
#    'monthly_cost': 1647.88,
#    'session_count': 11},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- North- Lilian To- PTurf/Mow/Maint',
#    'monthly_cost': 226.98000000000002,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Oppenheimer Pk PTurf Mow/Maint',
#    'monthly_cost': 690.71,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Pandora Pk PTurf Mow/Maint',
#    'monthly_cost': 1030.71,
#    'session_count': 7},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Price Pk PTurf Mow/Maint',
#    'monthly_cost': 236.35,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Prince Edward Pk PTurf Mow/Maint',
#    'monthly_cost': 411.25,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Renfrew Pk PTurf Mow/Maint',
#    'monthly_cost': 349.96000000000004,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Renfrew Ravine Pk PTurf Mow/Maint',
#    'monthly_cost': 184.35,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Robson Pk PTurf Mow/Maint',
#    'monthly_cost': 380.57,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Rupert Pk PTurf Mow/Maint',
#    'monthly_cost': 834.22,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Sahalli Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Salsbury Pk PTurf Mow/Maint',
#    'monthly_cost': 30.77,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Slocan Pk PTurf Mow/Maint',
#    'monthly_cost': 184.43,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Strathcona Linear Pk PTurf Mow/Main',
#    'monthly_cost': 453.8,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Strathcona Pk PTurf Mow/Maint',
#    'monthly_cost': 984.8599999999999,
#    'session_count': 5},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Sun Hop Pk PTurf Mow/Maint',
#    'monthly_cost': 227.06,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Sunnyside Pk PTurf Mow/Maint',
#    'monthly_cost': 288.43,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Sunrise Pk PTurf Mow/Maint',
#    'monthly_cost': 572.0,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Tea Swamp Pk PTurf Mow/Maint',
#    'monthly_cost': 226.9,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Templeton Pk PTurf Mow/Maint',
#    'monthly_cost': 432.53,
#    'session_count': 2},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Thornton Pk PTurf Mow/Maint',
#    'monthly_cost': 254.63,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Trillium Pk- Pass. Turf Mow/Maint',
#    'monthly_cost': 675.98,
#    'session_count': 3},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Victoria Pk PTurf Mow/Maint',
#    'monthly_cost': 489.38,
#    'session_count': 4},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- WC Shelley Pk PTurf Mow/Maint',
#    'monthly_cost': 61.53,
#    'session_count': 1},
#   {'year': '2025',
#    'month': '06',
#    'park': 'TFT- Woodland Pk PTurf Mow/Maint',
#    'monthly_cost': 312.0,
#    'session_count': 2}],
#  'rowcount': 517,
#  'elapsed_ms': 28,
#  'chart_type': 'line'}

# %% [markdown]
# ## mowing.cost_by_park_month

# %%
res = run_sql_template(
    "mowing.cost_by_park_month",
    {"month": 3, "year": 2025},
)

res
# Compare mowing costs across all parks in March 2025
# Out:
# {'rows': [{'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'total_cost': 2963.4700000000003,
#    'mowing_sessions': 15,
#    'avg_cost_per_session': 197.56466666666668,
#    'total_quantity': 49.0},
#   {'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'total_cost': 1709.14,
#    'mowing_sessions': 6,
#    'avg_cost_per_session': 284.8566666666667,
#    'total_quantity': 26.0},
#   {'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'total_cost': 1253.8799999999999,
#    'mowing_sessions': 8,
#    'avg_cost_per_session': 156.73499999999999,
#    'total_quantity': 23.0},
#   {'park': 'TFT- Cariboo Pk PTurf Mow/Maint',
#    'total_cost': 955.51,
#    'mowing_sessions': 6,
#    'avg_cost_per_session': 159.25166666666667,
#    'total_quantity': 19.0},
#   {'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'total_cost': 897.9699999999999,
#    'mowing_sessions': 4,
#    'avg_cost_per_session': 224.49249999999998,
#    'total_quantity': 13.0},
#   {'park': 'RFT- Hastings CC Pk PTurf Mow/Maint',
#    'total_cost': 798.04,
#    'mowing_sessions': 3,
#    'avg_cost_per_session': 266.0133333333333,
#    'total_quantity': 12.0},
#   {'park': 'RFT- Hastings Pk PTurf Mow/Maint',
#    'total_cost': 655.3,
#    'mowing_sessions': 2,
#    'avg_cost_per_session': 327.65,
#    'total_quantity': 10.0},
#   {'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'total_cost': 376.64,
#    'mowing_sessions': 3,
#    'avg_cost_per_session': 125.54666666666667,
#    'total_quantity': 6.0},
#   {'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'total_cost': 269.68,
#    'mowing_sessions': 2,
#    'avg_cost_per_session': 134.84,
#    'total_quantity': 4.0},
#   {'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'total_cost': 238.84,
#    'mowing_sessions': 2,
#    'avg_cost_per_session': 119.42,
#    'total_quantity': 4.0},
#   {'park': 'RFT- Gaston Pk PTurf Mow/Maint',
#    'total_cost': 238.84,
#    'mowing_sessions': 2,
#    'avg_cost_per_session': 119.42,
#    'total_quantity': 4.0},
#   {'park': 'RFT- China Cr Pk S PTurf Mow/Maint',
#    'total_cost': 194.73,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 194.73,
#    'total_quantity': 2.5},
#   {'park': 'RFT- Strathcona Pk PTurf Mow/Maint',
#    'total_cost': 120.32,
#    'mowing_sessions': 2,
#    'avg_cost_per_session': 60.16,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'total_cost': 120.32,
#    'mowing_sessions': 2,
#    'avg_cost_per_session': 60.16,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Melbourne Pk PTurf Mow/Maint',
#    'total_cost': 119.42,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 119.42,
#    'total_quantity': 2.0},
#   {'park': '"RFT- Templeton Pk- ""B"" Fields Mowing"',
#    'total_cost': 119.38,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 119.38,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Falaise Pk PTurf Mow/Maint',
#    'total_cost': 118.7,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 118.7,
#    'total_quantity': 1.5},
#   {'park': 'TFT- Renfrew Pk PTurf Mow/Maint',
#    'total_cost': 104.0,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 104.0,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Thunderbird Pk PTurf Mow/Maint',
#    'total_cost': 61.45,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 61.45,
#    'total_quantity': 1.0},
#   {'park': 'RFT- Evans Yard PTurf Mow/Maint',
#    'total_cost': 60.63,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 60.63,
#    'total_quantity': 1.0},
#   {'park': 'RFT- Price Pk PTurf Mow/Maint',
#    'total_cost': 59.69,
#    'mowing_sessions': 1,
#    'avg_cost_per_session': 59.69,
#    'total_quantity': 1.0}],
#  'rowcount': 21,
#  'elapsed_ms': 16,
#  'chart_type': 'bar'}

# %% [markdown]
# ## mowing.cost_breakdown

# %%
res = run_sql_template(
    "mowing.cost_breakdown",
    {# "park_name": "", 
     "month": 3, "year": 2025},
)

res
# What is the mowing cost breakdown in March 2025?
# Out:
# {'rows': [{'park': '"RFT- Templeton Pk- ""B"" Fields Mowing"',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 119.38,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P111',
#    'cost': 1394.4899999999998,
#    'sessions': 7,
#    'total_quantity': 23.0},
#   {'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 1193.8,
#    'sessions': 6,
#    'total_quantity': 20.0},
#   {'park': 'RFT- Cariboo Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P74',
#    'cost': 375.18,
#    'sessions': 2,
#    'total_quantity': 6.0},
#   {'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P111',
#    'cost': 60.63,
#    'sessions': 1,
#    'total_quantity': 1.0},
#   {'park': 'RFT- Carleton Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 59.69,
#    'sessions': 1,
#    'total_quantity': 1.0},
#   {'park': 'RFT- China Cr Pk S PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P43',
#    'cost': 194.73,
#    'sessions': 1,
#    'total_quantity': 2.5},
#   {'park': 'RFT- Evans Yard PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P111',
#    'cost': 60.63,
#    'sessions': 1,
#    'total_quantity': 1.0},
#   {'park': 'RFT- Falaise Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P246',
#    'cost': 118.7,
#    'sessions': 1,
#    'total_quantity': 1.5},
#   {'park': 'RFT- Gaston Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P22',
#    'cost': 238.84,
#    'sessions': 2,
#    'total_quantity': 4.0},
#   {'park': 'RFT- Hastings CC Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P28',
#    'cost': 499.59000000000003,
#    'sessions': 2,
#    'total_quantity': 7.0},
#   {'park': 'RFT- Hastings CC Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 298.45,
#    'sessions': 1,
#    'total_quantity': 5.0},
#   {'park': 'RFT- Hastings Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P28',
#    'cost': 356.85,
#    'sessions': 1,
#    'total_quantity': 5.0},
#   {'park': 'RFT- Hastings Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 298.45,
#    'sessions': 1,
#    'total_quantity': 5.0},
#   {'park': 'RFT- John Hendry Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P21',
#    'cost': 1253.8799999999999,
#    'sessions': 8,
#    'total_quantity': 23.0},
#   {'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P28',
#    'cost': 146.78,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Kaslo Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 122.9,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Melbourne Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P22',
#    'cost': 119.42,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P28',
#    'cost': 856.44,
#    'sessions': 3,
#    'total_quantity': 12.0},
#   {'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 477.52,
#    'sessions': 2,
#    'total_quantity': 8.0},
#   {'park': 'RFT- New Brighton Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P74',
#    'cost': 375.18,
#    'sessions': 1,
#    'total_quantity': 6.0},
#   {'park': 'RFT- Price Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 59.69,
#    'sessions': 1,
#    'total_quantity': 1.0},
#   {'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P74',
#    'cost': 128.6,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P111',
#    'cost': 125.14,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Renfrew Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 122.9,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Strathcona Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P111',
#    'cost': 60.63,
#    'sessions': 1,
#    'total_quantity': 1.0},
#   {'park': 'RFT- Strathcona Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 59.69,
#    'sessions': 1,
#    'total_quantity': 1.0},
#   {'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P43',
#    'cost': 389.45,
#    'sessions': 1,
#    'total_quantity': 5.0},
#   {'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P22',
#    'cost': 238.84,
#    'sessions': 1,
#    'total_quantity': 4.0},
#   {'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P28',
#    'cost': 146.78,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Sunrise Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 122.9,
#    'sessions': 1,
#    'total_quantity': 2.0},
#   {'park': 'RFT- Thunderbird Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P104',
#    'cost': 61.45,
#    'sessions': 1,
#    'total_quantity': 1.0},
#   {'park': 'TFT- Cariboo Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P102',
#    'cost': 955.51,
#    'sessions': 6,
#    'total_quantity': 19.0},
#   {'park': 'TFT- Hastings Emp Fields PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P22',
#    'cost': 238.84,
#    'sessions': 2,
#    'total_quantity': 4.0},
#   {'park': 'TFT- Renfrew Pk PTurf Mow/Maint',
#    'month': '03',
#    'activity_type': 'P102',
#    'cost': 104.0,
#    'sessions': 1,
#    'total_quantity': 2.0}],
#  'rowcount': 35,
#  'elapsed_ms': 2}

# %% [markdown]
# ## field_dimension.rectangular

# %%
res = run_sql_template(
    "field_dimension.rectangular",
    {},
)

res

# Table only: compare soccer U12 9v9 field length and width
# Out:
# {'rows': [{'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Rectangular Field Dimension: Length - m "': 'Rectangular Field Dimension: Length - m ',
#    '"Rectangular Field Dimension: Width - m "': 'Rectangular Field Dimension: Width - m '}],
#  'rowcount': 10,
#  'elapsed_ms': 40}

# %% [markdown]
# ## field_dimension.diamond

# %%
res = run_sql_template(
    "field_dimension.diamond",
    {},
)

res

# Rows only: U15 field length and width (diamonds), no explanation.
# Out:
# {'rows': [{'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '},
#   {'"Name of Field "': 'Name of Field ',
#    '"Diamonds: Dimension Home to Pitchers Plate - m "': 'Diamonds: Dimension Home to Pitchers Plate - m ',
#    '"Diamonds: Home to First Base Path - m "': 'Diamonds: Home to First Base Path - m '}],
#  'rowcount': 10,
#  'elapsed_ms': 2}

# %% [markdown]
# ## mowing.cost_by_park_least_per_sqft

# %%
res = run_sql_template(
    "mowing.cost_by_park_least_per_sqft",
    {"month1": 6, "month2": 5, "year1": 2024, "year2": 2025},
)

res

# Which parks have the least mowing cost from June 2024 to May 2025?
# Out:
# {'rows': [{'park_name': 'Robson Park',
#    'total_cost': 389.3,
#    'area_sqft': 15639.92,
#    'cost_per_sqft': 0.0249},
#   {'park_name': 'Prince Edward Park',
#    'total_cost': 461.49,
#    'area_sqft': 12163.1,
#    'cost_per_sqft': 0.0379},
#   {'park_name': 'Slocan Park',
#    'total_cost': 1821.94,
#    'area_sqft': 42116.82,
#    'cost_per_sqft': 0.0433},
#   {'park_name': 'Trillium Park',
#    'total_cost': 1425.63,
#    'area_sqft': 30488.56,
#    'cost_per_sqft': 0.0468},
#   {'park_name': 'John Hendry (Trout Lake) Park',
#    'total_cost': 13579.67,
#    'area_sqft': 273711.24,
#    'cost_per_sqft': 0.0496},
#   {'park_name': 'Rupert Park',
#    'total_cost': 6324.71,
#    'area_sqft': 118277.63,
#    'cost_per_sqft': 0.0535},
#   {'park_name': 'Woodland Park',
#    'total_cost': 865.56,
#    'area_sqft': 15834.06,
#    'cost_per_sqft': 0.0547},
#   {'park_name': 'Falaise Park',
#    'total_cost': 4391.68,
#    'area_sqft': 75832.44,
#    'cost_per_sqft': 0.0579},
#   {'park_name': 'Beaconsfield Park',
#    'total_cost': 2655.88,
#    'area_sqft': 44420.15,
#    'cost_per_sqft': 0.0598},
#   {'park_name': 'Thornton Park',
#    'total_cost': 895.14,
#    'area_sqft': 14968.41,
#    'cost_per_sqft': 0.0598}],
#  'rowcount': 10,
#  'elapsed_ms': 8,
#  'chart_type': 'bar',
#  'period': '6/2024 to 5/2025'}

# %% [markdown]
# ## activity.cost_by_location_range

# %%
res = run_sql_template(
    "activity.cost_by_location_range",
    {
        "park_name": "Stanley",
        "month1": 2,
        "month2": 3,
        "year1": 2025,
        "year2": 2025,
        # "activity_name": "mow",  # optional keyword filter
    },
)

res

# What is the cost of the activity in Stanley from February 2025 to March 2025?
# Out:
# {'rows': [{'location': 'STANLEY',
#    'activity_description': 'Snow Removal',
#    'activity_cost': 3036.2,
#    'first_date': '2025-02-03',
#    'last_date': '2025-02-04',
#    'work_orders': 6},
#   {'location': 'STANLEY',
#    'activity_description': 'Beds Maintenance',
#    'activity_cost': 2268.98,
#    'first_date': '2025-02-26',
#    'last_date': '2025-03-07',
#    'work_orders': 2},
#   {'location': 'STANLEY',
#    'activity_description': 'Administration ',
#    'activity_cost': 1579.56,
#    'first_date': '2025-02-20',
#    'last_date': '2025-02-20',
#    'work_orders': 2},
#   {'location': 'STANLEY',
#    'activity_description': 'Path/Court/Parking',
#    'activity_cost': 298.55,
#    'first_date': '2025-03-07',
#    'last_date': '2025-03-07',
#    'work_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': '"B" Fields Maintenance',
#    'activity_cost': 194.73,
#    'first_date': '2025-02-18',
#    'last_date': '2025-02-18',
#    'work_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': 'Tree Maintenance',
#    'activity_cost': 100.58,
#    'first_date': '2025-02-13',
#    'last_date': '2025-02-13',
#    'work_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': 'Leaf Removal',
#    'activity_cost': 55.0,
#    'first_date': '2025-02-10',
#    'last_date': '2025-02-10',
#    'work_orders': 1}],
#  'rowcount': 7,
#  'elapsed_ms': 1,
#  'chart_type': 'bar',
#  'period': '02/2025 to 03/2025'}

# %% [markdown]
# ## activity.last_activity_date

# %%
res = run_sql_template(
    "activity.last_activity_date",
    {"park_name": "Stanley"},
)

res

# What is the latest activity in Stanley?
# Out:
# {'rows': [{'location': 'STANLEY',
#    'activity_description': 'Beds Maintenance',
#    'last_actual_start': '2025-03-07',
#    'total_orders': 10},
#   {'location': 'STANLEY',
#    'activity_description': 'Path/Court/Parking',
#    'last_actual_start': '2025-03-07',
#    'total_orders': 7},
#   {'location': 'STANLEY',
#    'activity_description': 'Administration ',
#    'last_actual_start': '2025-02-20',
#    'total_orders': 4},
#   {'location': 'STANLEY',
#    'activity_description': '"B" Fields Maintenance',
#    'last_actual_start': '2025-02-18',
#    'total_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': 'Tree Maintenance',
#    'last_actual_start': '2025-02-13',
#    'total_orders': 5},
#   {'location': 'STANLEY',
#    'activity_description': 'Leaf Removal',
#    'last_actual_start': '2025-02-10',
#    'total_orders': 8},
#   {'location': 'STANLEY',
#    'activity_description': 'Snow Removal',
#    'last_actual_start': '2025-02-04',
#    'total_orders': 8},
#   {'location': 'STANLEY',
#    'activity_description': 'Refuse Removal / Tide Line Cleanup',
#    'last_actual_start': '2025-01-29',
#    'total_orders': 3},
#   {'location': 'STANLEY',
#    'activity_description': 'Paper Picking',
#    'last_actual_start': '2025-01-24',
#    'total_orders': 8},
#   {'location': 'STANLEY',
#    'activity_description': 'Pass. Turf Mow/Maint',
#    'last_actual_start': '2024-12-30',
#    'total_orders': 3},
#   {'location': 'STANLEY',
#    'activity_description': 'Water Bodies Maintenance',
#    'last_actual_start': '2024-12-20',
#    'total_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': '"A" Fields Maintenance',
#    'last_actual_start': '2024-12-19',
#    'total_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': 'Goose Waste Removal',
#    'last_actual_start': '2024-12-17',
#    'total_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': 'Unpaved Surface Maint',
#    'last_actual_start': '2024-12-17',
#    'total_orders': 1},
#   {'location': 'STANLEY',
#    'activity_description': 'Ball Diamonds Maintenance',
#    'last_actual_start': '2024-12-13',
#    'total_orders': 1}],
#  'rowcount': 15,
#  'elapsed_ms': 7}

# %% [markdown]
# ## activity.maintenance_due_window

# %%
res = run_sql_template(
    "activity.maintenance_due_window",
    {"activity_name": "maintenance", "weeks_ahead": 10 #park_name: optional
     },
)

res

# Table only: maintenance activities due within 3 weeks by park.
# Out:
# {'rows': [{'location': 'STANLEY',
#    'activity_description': 'Ball Diamonds Maintenance',
#    'last_service_date': '2024-12-13',
#    'days_since_last': 345.1,
#    'total_orders': 1,
#    'weeks_ahead': 10,
#    'horizon_days': 70},
#   {'location': 'STANLEY',
#    'activity_description': '"A" Fields Maintenance',
#    'last_service_date': '2024-12-19',
#    'days_since_last': 339.1,
#    'total_orders': 1,
#    'weeks_ahead': 10,
#    'horizon_days': 70},
#   {'location': 'STANLEY',
#    'activity_description': 'Water Bodies Maintenance',
#    'last_service_date': '2024-12-20',
#    'days_since_last': 338.1,
#    'total_orders': 1,
#    'weeks_ahead': 10,
#    'horizon_days': 70},
#   {'location': 'STANLEY',
#    'activity_description': 'Tree Maintenance',
#    'last_service_date': '2025-02-13',
#    'days_since_last': 283.1,
#    'total_orders': 5,
#    'weeks_ahead': 10,
#    'horizon_days': 70},
#   {'location': 'STANLEY',
#    'activity_description': '"B" Fields Maintenance',
#    'last_service_date': '2025-02-18',
#    'days_since_last': 278.1,
#    'total_orders': 1,
#    'weeks_ahead': 10,
#    'horizon_days': 70},
#   {'location': 'STANLEY',
#    'activity_description': 'Beds Maintenance',
#    'last_service_date': '2025-03-07',
#    'days_since_last': 261.1,
#    'total_orders': 10,
#    'weeks_ahead': 10,
#    'horizon_days': 70}],
#  'rowcount': 6,
#  'elapsed_ms': 1,
#  'chart_type': 'timeline',
#  'horizon_days': 70}
